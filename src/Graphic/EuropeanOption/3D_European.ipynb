# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_call.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Call Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_call.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.view_init(elev=45, azim=120)
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Call Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_put.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Put Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_put.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.view_init(elev=45, azim=120)
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Put Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %% [markdown]
# _______________

# %% [markdown]
# Crank_nicolson_method

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_crank_nicolson_put.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Put Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_crank_nicolson_put.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.view_init(elev=45, azim=120)
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Put Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_crank_nicolson_call.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Call Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

risk_free_rate = 0.05
volatility = 0.2

# Load data
data = np.loadtxt("option_values_crank_nicolson_call.txt")
time = np.unique(data[:, 0])  # Time steps
stock_prices = np.unique(data[:, 1])  # Stock prices

# Reshape data
T, S = np.meshgrid(time, stock_prices)
V = data[:, 2].reshape(len(stock_prices), len(time)).T

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(S, T, V, cmap='viridis')
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)  # Add color bar
ax.view_init(elev=45, azim=120)
ax.set_xlabel('Stock Price (S)')
ax.set_ylabel('Time (t in years)')
ax.set_zlabel('Option Price (V)')
plt.title(f'Call Option Price Evolution with the risk-free rate: {risk_free_rate} and Volatility: {volatility}')
plt.show()
